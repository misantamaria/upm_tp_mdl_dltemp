# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Time Series | Part II: Preprocessing and analysis
#
# This is the second Notebook is related to Part II: Preprocessing and analysis. You will find exercises on preprocessing datasets and exploring EDA technques for time series data.
#
# Go Learn!

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Load the multivariate time series data
data = pd.read_csv('/mnt/data/multivariate_timeseries.csv', index_col=0, parse_dates=True)

# Visualize each series in the multivariate dataset
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 8), sharex=True)
for i, col in enumerate(data.columns):
    axes[i].plot(data[col].dropna(), label=f'Series {i+1}')
    axes[i].set_title(f'Series {i+1}')
    axes[i].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Handling Non-Equal Lengths
# Pad shorter series to match the longest one in the dataset.

# %%
# Padding non-equal length time series
data_aligned = data.apply(lambda x: x.resample('D').pad())

# Visualize the aligned data
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 8), sharex=True)
for i, col in enumerate(data_aligned.columns):
    axes[i].plot(data_aligned[col], label=f'Padded Series {i+1}')
    axes[i].set_title(f'Padded Series {i+1}')
    axes[i].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyze with Kaggle Dataset
# Now,  let's go with a real-world dataset. We are going to practice what we have learnt above. The goal is to preprocess [kaggle electric-power-consumption-data-set](https://www.kaggle.com/datasets/uciml/electric-power-consumption-data-set) dataset for future forecasting (guessing the future) task. This dataset contains measures of electric power consumption in a single household. Try to infer as much information you can from the data.
#
# ### [8/10] Exercise <N>
# Your task is to prepare a dataframe and save it as .csv file. The dataframe must have roes with sliding windows for all the variables using window size ``w = 5 min''. Thus, there must be a column for the timestamp ``t'' and a column per variable.
